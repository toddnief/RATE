# %%
from rate.constants import EFFECTS_DIR
from rate.utils_plotting import synthetic_plot
# Out:
# 2024-11-21 16:01:02,453 - INFO - Note: NumExpr detected 64 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# 2024-11-21 16:01:02,455 - INFO - NumExpr defaulting to 16 threads.

# %%
templates = [
{
        "dataset_name": "IMDB",
        "score": "ArmoRM",
        "dataset_filename": "ArmoRM/imdb_vowels_armorm_treatment_effects_20241120_172602_typos_0.json"
    },
{
        "dataset_name": "IMDB",
        "score": "ArmoRM",
        "dataset_filename": "ArmoRM/imdb_vowels_armorm_treatment_effects_20241120_172629_typos_5.json"
    },
{
        "dataset_name": "IMDB",
        "score": "ArmoRM",
        "dataset_filename": "ArmoRM/imdb_vowels_armorm_treatment_effects_20241120_172642_typos_10.json"
    },
{
        "dataset_name": "IMDB",
        "score": "ArmoRM",
        "dataset_filename": "ArmoRM/imdb_vowels_armorm_treatment_effects_20241120_172701_typos_15.json"
    },
{
        "dataset_name": "IMDB",
        "score": "ArmoRM",
        "dataset_filename": "ArmoRM/imdb_vowels_armorm_treatment_effects_20241120_172714_typos_20.json"
    },
{
        "dataset_name": "IMDB",
        "score": "ArmoRM",
        "dataset_filename": "ArmoRM/imdb_vowels_armorm_treatment_effects_20241120_172727_typos_25.json"
    },
{
        "dataset_name": "IMDB",
        "score": "ArmoRM",
        "dataset_filename": "ArmoRM/imdb_vowels_armorm_treatment_effects_20241120_172741_typos_30.json"
    }
]

# %%
# get effects_template from reading the json files in the templates
data_list = []
import json
for template in templates:
    with open(f"{EFFECTS_DIR}/typos/{template['dataset_filename']}") as f:
        data_list.append(json.load(f))

# %%
synthetic_plot(data_list, templates, "Starts w/ Vowel", "Typos", "Percentage of Typos")
# Out:
# Slope of $\widehat{\text{ATE}} \, (\text{Rewrite}^2)$: 0.0000
# Slope of $\widehat{\text{ATE}} \, (\text{Single Rewrite})$: -0.0002

# %%
templates = [
{
        "dataset_name": "IMDB",
        "score": "NCSOFT/Llama-3-OffsetBias-RM-8B",
        "dataset_filename": "NCSOFT/imdb_vowels_ncsoft_treatment_effects_20241120_173319_typos_0.json"
    },
{
        "dataset_name": "IMDB",
        "score": "NCSOFT/Llama-3-OffsetBias-RM-8B",
        "dataset_filename": "NCSOFT/imdb_vowels_ncsoft_treatment_effects_20241120_173332_typos_5.json"
    },
{
        "dataset_name": "IMDB",
        "score": "NCSOFT/Llama-3-OffsetBias-RM-8B",
        "dataset_filename": "NCSOFT/imdb_vowels_ncsoft_treatment_effects_20241120_173348_typos_10.json"
    },
{
        "dataset_name": "IMDB",
        "score": "NCSOFT/Llama-3-OffsetBias-RM-8B",
        "dataset_filename": "NCSOFT/imdb_vowels_ncsoft_treatment_effects_20241120_173359_typos_15.json"
    },
{
        "dataset_name": "IMDB",
        "score": "NCSOFT/Llama-3-OffsetBias-RM-8B",
        "dataset_filename": "NCSOFT/imdb_vowels_ncsoft_treatment_effects_20241120_173407_typos_20.json"
    },
{
        "dataset_name": "IMDB",
        "score": "NCSOFT/Llama-3-OffsetBias-RM-8B",
        "dataset_filename": "NCSOFT/imdb_vowels_ncsoft_treatment_effects_20241120_173420_typos_25.json"
    },
{
        "dataset_name": "IMDB",
        "score": "NCSOFT/Llama-3-OffsetBias-RM-8B",
        "dataset_filename": "NCSOFT/imdb_vowels_ncsoft_treatment_effects_20241120_173429_typos_30.json"
    }
]

# %%
# get effects_template from reading the json files in the templates
data_list = []
import json
for template in templates:
    with open(f"{EFFECTS_DIR}/typos/{template['dataset_filename']}") as f:
        data_list.append(json.load(f))

# %%
synthetic_plot(data_list, templates, "Starts w/ Vowel", "Typos", "Percentage of Typos")
# Out:
# Slope of $\widehat{\text{ATE}} \, (\text{Rewrite}^2)$: 0.0008
# Slope of $\widehat{\text{ATE}} \, (\text{Single Rewrite})$: -0.0071

# %%
templates = [
{
        "dataset_name": "IMDB",
        "score": "FsfairX-LLaMA3-RM-v0.1",
        "dataset_filename": "sfairXC/imdb_vowels_sfairXC_treatment_effects_20241120_173040_typos_0.json"
    },
{
        "dataset_name": "IMDB",
        "score": "FsfairX-LLaMA3-RM-v0.1",
        "dataset_filename": "sfairXC/imdb_vowels_sfairXC_treatment_effects_20241120_173052_typos_5.json"
    },
{
        "dataset_name": "IMDB",
        "score": "FsfairX-LLaMA3-RM-v0.1",
        "dataset_filename": "sfairXC/imdb_vowels_sfairXC_treatment_effects_20241120_173100_typos_10.json"
    },
{
        "dataset_name": "IMDB",
        "score": "FsfairX-LLaMA3-RM-v0.1",
        "dataset_filename": "sfairXC/imdb_vowels_sfairXC_treatment_effects_20241120_173110_typos_15.json"
    },
{
        "dataset_name": "IMDB",
        "score": "FsfairX-LLaMA3-RM-v0.1",
        "dataset_filename": "sfairXC/imdb_vowels_sfairXC_treatment_effects_20241120_173128_typos_20.json"
    },
{
        "dataset_name": "IMDB",
        "score": "FsfairX-LLaMA3-RM-v0.1",
        "dataset_filename": "sfairXC/imdb_vowels_sfairXC_treatment_effects_20241120_173153_typos_25.json"
    },
{
        "dataset_name": "IMDB",
        "score": "FsfairX-LLaMA3-RM-v0.1",
        "dataset_filename": "sfairXC/imdb_vowels_sfairXC_treatment_effects_20241120_173214_typos_30.json"
    }
]

# %%
# get effects_template from reading the json files in the templates
data_list = []
import json
for template in templates:
    with open(f"{EFFECTS_DIR}/typos/{template['dataset_filename']}") as f:
        data_list.append(json.load(f))

# %%
synthetic_plot(data_list, templates, "Starts w/ Vowel", "Typos", "Percentage of Typos")
# Out:
# Slope of $\widehat{\text{ATE}} \, (\text{Rewrite}^2)$: 0.0014
# Slope of $\widehat{\text{ATE}} \, (\text{Single Rewrite})$: -0.0133
